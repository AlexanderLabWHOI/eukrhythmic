# %%
import subprocess
import numpy as np
import pandas as pd
import os

# %%
# first, we need to grab what the sample names and assemblies are
resultsfold = "/vortexfs1/omics/saito/BATS2019-clio-metaT/eukrhythmic_output"
os.path.join("", "vortexfs1", "omics", "alexander", "ncohen", "BATS2019-clio-metaT", resultsfold)
resultsfold = "/vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/22May_stolen"
#os.path.join("", "vortexfs1", "omics", "alexander", "ncohen", "BATS2019-clio-metaT","20Apr2020")
indiv_salmon = os.path.join(resultsfold, \
                           "salmon_indiv", "salmon_quant_assembly*")

# %%
data_dir = resultsfold

indiv_salmon = os.path.join(resultsfold, \
                           "salmon_indiv", "salmon_quant_assembly*", "aux_info", "meta_info.json")

result = os.system('grep --with-filename percent_mapped /' + indiv_salmon + " > indiv_salmon.txt")

# %%
print(indiv_salmon)
indiv_salmon_frame = pd.read_csv("indiv_salmon.txt", sep = ":", header = None, names = ["Path","Metric","Value"])
indiv_salmon_frame["Value"] = [float(curr.split(",")[0]) for curr in indiv_salmon_frame["Value"]]
indiv_salmon_frame["Path"] = [curr.split("/")[len(curr.split("/"))-3] for curr in indiv_salmon_frame["Path"]]
indiv_salmon_frame
# Out:
# /vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/22May_stolen/salmon_indiv/salmon_quant_assembly*/aux_info/meta_info.json
#                                    Path                Metric      Value
# 0   salmon_quant_assembly_HN004_megahit      "percent_mapped"  86.141806
# 1   salmon_quant_assembly_HN004_trinity      "percent_mapped"  88.239501
# 2    salmon_quant_assembly_HN004_velvet      "percent_mapped"  61.848977
# 3   salmon_quant_assembly_HN007_megahit      "percent_mapped"  91.864576
# 4   salmon_quant_assembly_HN007_trinity      "percent_mapped"  91.942100
# ..                                  ...                   ...        ...
# 61  salmon_quant_assembly_HN040_trinity      "percent_mapped"  87.703927
# 62   salmon_quant_assembly_HN040_velvet      "percent_mapped"  59.903603
# 63  salmon_quant_assembly_HN043_megahit      "percent_mapped"  87.482370
# 64  salmon_quant_assembly_HN043_trinity      "percent_mapped"  87.810889
# 65   salmon_quant_assembly_HN043_velvet      "percent_mapped"  59.870131
#
# [66 rows x 3 columns]

# %%
indiv_salmon = os.path.join(resultsfold, "salmon", "salmon_quant_assembly*", "aux_info", "meta_info.json")
result = os.system('grep --with-filename percent_mapped /' + indiv_salmon + " > merged_salmon.txt")

indiv_salmon_frame = pd.read_csv("merged_salmon.txt", sep = ":", header = None, names = ["Path","Metric","Value"])
indiv_salmon_frame["Value"] = [float(curr.split(",")[0]) for curr in indiv_salmon_frame["Value"]]
indiv_salmon_frame["Path"] = [curr.split("/")[len(curr.split("/"))-3] for curr in indiv_salmon_frame["Path"]]
indiv_salmon_frame
# Out:
#                            Path                Metric      Value
# 0  salmon_quant_assembly_merged      "percent_mapped"  78.406518

# %%
merged_assemblies = os.path.join("/", "vortexfs1", "omics", "alexander", "ncohen", "BATS2019-clio-metaT", "20Apr2020", "merged")

listedfiles = os.listdir(merged_assemblies)
sizes = [(os.path.join(merged_assemblies, path), os.stat(os.path.join(merged_assemblies, path)).st_size) for path in listedfiles]

## Grab the file sizes and translate them to an easy-to-understand form: 

filesizes = [float(curr[1]) / (1*10**9) for curr in sizes]
filenames = [curr[0].split("/")[len(curr[0].split("/")) - 1] for curr in sizes]
mergednottrans = pd.DataFrame({"Name": filenames, "Size in GB": filesizes})
mergednottrans
# Out:
#                  Name  Size in GB
# 0  HN004_merged.fasta    0.415983
# 1  HN007_merged.fasta    0.255969
# 2  HN017_merged.fasta    0.882940
# 3  HN027_merged.fasta    0.143708
# 4  HN008_merged.fasta    0.193300

# %%
transdecoded_assemblies = os.path.join("/", "vortexfs1", "omics", "alexander", "ncohen", "BATS2019-clio-metaT", "20Apr2020", "transdecoder")

listedfiles = os.listdir(transdecoded_assemblies)
sizes = [(os.path.join(transdecoded_assemblies, path), os.stat(os.path.join(transdecoded_assemblies, path)).st_size) for path in listedfiles]
sizes = [curr for curr in sizes if "cds" in curr[0]]
print(sizes)
## Grab the file sizes and translate them to an easy-to-understand form: 

filesizes = [float(curr[1]) / (1*10**9) for curr in sizes]
filenames = [curr[0].split("/")[len(curr[0].split("/")) - 1] for curr in sizes]
transd = pd.DataFrame({"Name": filenames, "Size in GB": filesizes})
pd.concat([transd, mergednottrans])
# Out:
# [('/vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/20Apr2020/transdecoder/HN004.fasta.transdecoder.cds', 178793046), ('/vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/20Apr2020/transdecoder/HN007.fasta.transdecoder.cds', 130265519), ('/vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/20Apr2020/transdecoder/HN027.fasta.transdecoder.cds', 56081762), ('/vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/20Apr2020/transdecoder/merged.fasta.transdecoder.cds', 717612114), ('/vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/20Apr2020/transdecoder/HN017.fasta.transdecoder.cds', 518177548), ('/vortexfs1/omics/alexander/ncohen/BATS2019-clio-metaT/20Apr2020/transdecoder/HN008.fasta.transdecoder.cds', 69293476)]
#                             Name  Size in GB
# 0   HN004.fasta.transdecoder.cds    0.178793
# 1   HN007.fasta.transdecoder.cds    0.130266
# 2   HN027.fasta.transdecoder.cds    0.056082
# 3  merged.fasta.transdecoder.cds    0.717612
# 4   HN017.fasta.transdecoder.cds    0.518178
# 5   HN008.fasta.transdecoder.cds    0.069293
# 0             HN004_merged.fasta    0.415983
# 1             HN007_merged.fasta    0.255969
# 2             HN017_merged.fasta    0.882940
# 3             HN027_merged.fasta    0.143708
# 4             HN008_merged.fasta    0.193300

# %%
merged_assemblies = os.path.join("/", "vortexfs1", "omics", "alexander", "ncohen", "BATS2019-clio-metaT", "20Apr2020", "merged_all")

listedfiles = os.listdir(merged_assemblies)
sizes = [(os.path.join(merged_assemblies, path), os.stat(os.path.join(merged_assemblies, path)).st_size) for path in listedfiles]

## Grab the file sizes and translate them to an easy-to-understand form: 

filesizes = [float(curr[1]) / (1*10**9) for curr in sizes]
filenames = [curr[0].split("/")[len(curr[0].split("/")) - 1] for curr in sizes]
pd.concat([pd.DataFrame({"Name": filenames, "Size in GB": filesizes}),\
           transd.loc[transd["Name"] == "merged.fasta.transdecoder.cds",:]])
# Out:
#                             Name  Size in GB
# 0                   merged.fasta    1.891900
# 3  merged.fasta.transdecoder.cds    0.717612
